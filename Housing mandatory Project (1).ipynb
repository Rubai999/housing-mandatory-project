# %% [markdown]
# # INTRODUCTION:--

# %%
'''The Housing Dataset Project aims to analyze and understand various factors influencing housing prices and patterns.
The dataset consists of several columns,each providing valuable information about different aspects of housing properties. 
Let's explore the key columns in the dataset:

1.longitude
2.latitude
3.housing_median_age
4.total_rooms
5.total_bedrooms
6.population
7.households
8.median_income
9.median_house_value
10.ocean_proximity

By analyzing and exploring the relationships between these columns,
we can gain valuable insights into housing market trends, factors affecting housing prices, 
and the impact of various features on housing availability and affordability. 

This project aims to utilize the dataset to uncover patterns, make predictions, 
and assist in informed decision-making in the real estate domain.

# %%
house=pd.read_excel("C:\\Users\\RUBAI PANDEY\\Downloads\\housing.xlsx")
house
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
pip install pandas
# Out:
# ...
#
# ...

# %% [markdown]
# # 1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.

# %%
# step 1-Importing the necessary libraries:

import pandas as pd
import matplotlib.pyplot as plt

# step 2-Reading the Excel file into a pandas DataFrame:

house=pd.read_excel("C:\\Users\\RUBAI PANDEY\\Downloads\\housing.xlsx")

# step 3-Calculating the average median income:

avg_median_income = house['median_income'].mean()
print("Average Median Income:", avg_median_income)

# plt.figure(figsize=(8,4)) sets the figure size to 8 inches wide and 4 inches tall.
plt.figure(figsize=(8,4))

''' plt.hist() creates a histogram using the 'median_income' column from the DataFrame house. 
It specifies bins=20 to divide the range of values into 20 equally spaced bins. 
The edgecolor='black' argument sets the color of the edges of the bars in the histogram.'''

plt.hist(house['median_income'], bins=20, edgecolor='black')


'''plt.xlabel(), plt.ylabel(), and plt.title() are used to set the labels and title for the x-axis, y-axis, and the plot, 
respectively.'''


plt.xlabel('Median Income')
plt.ylabel('Frequency')
plt.title('Distribution of median income')

# plt.show() displays the histogram plot on the screen.
plt.show()
# Out:
# Average Median Income: 3.8706710029069766

# %%
'''Here's an explanation of the distribution based on the histogram plot:

1.Shape:

From the histogram, we can observe the shape of the distribution. 
It appears to be slightly right-skewed, meaning that the tail of the distribution extends towards higher median income values. 
This indicates that there are relatively fewer data points with very low median incomes and 
a higher concentration of data points in the middle to higher income range.

2.Peaks and Gaps:

The histogram may exhibit peaks and gaps, indicating concentrations and gaps in the frequency of median income values.
In this case, based on the histogram, we can see a noticeable peak around the range of approximately 3 to 4. 
This suggests that there is a relatively higher frequency of median income values falling within this range.
It implies that a significant number of individuals or households in the dataset have median incomes within this specific range.

3.Range:

The x-axis of the histogram represents the range of median income values divided into bins.
In this case, it seems to span from approximately 0 to 10, indicating the range of median incomes covered by the dataset.

4.Frequency:

The y-axis of the histogram represents the frequency or count of data points falling within each bin.
The height of each bar corresponds to the number of data points (individuals or households)
that have a median income falling within that specific income range.


Overall, based on the provided histogram plot, the distribution of median income values in the dataset appears slightly right-skewed, with a peak around the range of 3 to 4.
This suggests that there is a concentration of individuals or households with median incomes in that range.'''

# %% [markdown]
# # 2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

# %%
# step1-Importing the necessary libraries:
import pandas as pd
import matplotlib.pyplot as plt

# strp 2=Reading the Excel file into a pandas DataFrame:

housing_data=pd.read_excel("C:\\Users\\RUBAI PANDEY\\Downloads\\housing.xlsx")


# step 3-Creating the histogram plot:

# plt.figure(figsize=(8, 4)) sets the figure size to 8 inches wide and 4 inches tall.
# plt.hist() creates a histogram using the 'housing_median_age' column from the DataFrame housing_data. It specifies bins=20 to divide the range of values into 20 equally spaced bins. 
# The edgecolor='black' argument sets the color of the edges of the bars in the histogram.
# plt.xlabel(), plt.ylabel(), and plt.title() are used to set the labels and title for the x-axis, y-axis, and the plot, respectively.
# plt.show() displays the histogram plot on the screen.


plt.figure(figsize=(8, 4))
plt.hist(housing_data['housing_median_age'], bins=20, edgecolor='black')
plt.xlabel('Housing Median Age')
plt.ylabel('Frequency')
plt.title('Distribution of Housing Median Age')
plt.show()

# %%
'''observations:-
1.The plot indicates the mode(s) of the housing median age, which are the peaks or highest bars in the histogram.
The most frequent housing median age values are around 15-20 years,25-28 and 32-40 years.
2.The histogram is symmetric here.At the age of 15 and 32-35 the frequency is higher that means 
the count of housing is at the top among these particular groups of people.
3.The distribution is bimodal here.'''

# %% [markdown]
# # 3.Show with the help of visualization, how median_income and median_house_values are related?

# %%
# step 1-importing necessary library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#step 2-reading the excel file in pandas dataframe 

housing_data = pd.read_excel("C:\\Users\\RUBAI PANDEY\\Downloads\\housing.xlsx")

# step 3-Creating seaborn scatterplot

sns.scatterplot(x='median_income', y='median_house_value', data=housing_data)
plt.xlabel('Median Income')
plt.ylabel('Median House Value')
plt.title('Relationship between Median Income and Median House Value')
plt.show()

# %%
'''observations-

1.The plot shows a positive correlation between 'median_income' and 'median_house_value'. As the 'median_income' increases, 
there is a tendency for the 'median_house_value' to increase as well. 
This indicates that higher income areas tend to have higher house values.

2. The majority of the data points are concentrated in a specific range of 'median_income' and 'median_house_value'. 
This suggests that there may be certain income and house value ranges that are more common in the dataset.

3.There are some outliers in the data where 'median_income' is relatively high but 'median_house_value' is low or vice versa. 
These points deviate from the overall trend and may represent unique cases or anomalies in the data.

4.There appears to be a ceiling effect for 'median_house_value' as it reaches a maximum value and does not increase further,
even for higher 'median_income' values.That means after a certain point the data concentration is decreases.'''

# %% [markdown]
# # 4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

# %%
# step 1-Importing the necessary library
import pandas as pd

# step 2-Assigning the file path to a variable:
original_dataset_path ="C:\\Users\\RUBAI PANDEY\\Downloads\\housing.xlsx"

# step 3-Reading the Excel file into a pandas DataFrame:
original_dataset = pd.read_excel(original_dataset_path)

# step 4-Dropping rows with missing values:
new_dataset = original_dataset.dropna(subset=['total_bedrooms'])

# step 5-Printing the first 5 rows of the new dataset:
print(new_dataset.head(5))
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
'''Observation:
By deleting the examples (rows) with missing values in the 'total_bedrooms' column,
the new dataset ensures that it only contains complete examples where the 'total_bedrooms' values are available.
This can be useful when missing values are not suitable for imputation or when the analysis requires complete data. '''

# %% [markdown]
# # 5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

# %%
# step 1-Importing the necessary library:
import pandas as pd

# step 2-Assigning the file path to a variable:
original_dataset_path ="C:\\Users\\RUBAI PANDEY\\Downloads\\housing.xlsx"

# step 3-Reading the Excel file into a pandas DataFrame:


original_dataset = pd.read_excel(original_dataset_path)

# step 4-Calculating the mean value of 'total_bedrooms':

mean_total_bedrooms = original_dataset['total_bedrooms'].mean()

# step 5-Filling missing values with the mean value:
new_dataset = original_dataset.fillna({'total_bedrooms': mean_total_bedrooms})

# step 6-printing the dataset
print(new_dataset.head(5))
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
'''explanation of the observation:
By filling the missing values with the mean value of 'total_bedrooms', 
the new dataset ensures that there are no missing values in the 'total_bedrooms' column.
This makes the dataset more complete and suitable for further analysis.'''

# %% [markdown]
# # 6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.

# %%
def calculate_median(dataset):
    sorted_data = sorted(dataset)
    n = len(sorted_data)
    
    if n % 2 == 0:
        mid1 = n // 2
        mid2 = mid1 - 1
        median = (sorted_data[mid1] + sorted_data[mid2]) / 2
    else:
        mid = n // 2
        median = sorted_data[mid]
    
    return median

# %% [markdown]
# # 7. Plot latitude versus longitude and explain your observations.

# %%
#step 1- Importing the necessary libraries:

import pandas as pd
import matplotlib.pyplot as plt

# step 2-Assigning the file path to a variable:
housing_data="C:\\Users\\RUBAI PANDEY\\Downloads\\housing.xlsx"

# step 3-Reading the Excel file into a pandas DataFrame:
h_dataset= pd.read_excel(housing_data)

# step 4-Extracting latitude and longitude columns:

latitude = h_dataset['latitude']
longitude = h_dataset['longitude']

# step 5-Creating the scatter plot:

# plt.scatter() creates a scatter plot using the 'longitude' column as the x-axis values and the 'latitude' column as the y-axis values. 
# The alpha=0.5 argument sets the transparency of the data points to 0.5, making them partially transparent.
# plt.xlabel() and plt.ylabel() set the labels for the x-axis and y-axis, respectively.
# plt.title() sets the title for the plot.
# plt.show() displays the scatter plot on the screen.


plt.scatter(longitude, latitude, alpha=0.5)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Latitude vs Longitude')
plt.show()

# %%
'''explanation:--
    
The scatter plot of latitude versus longitude provides a visual representation of the geographic distribution of the data points. 
It helps us observe any patterns, clusters, or outliers in the data,
providing insights into the spatial relationships and geographic characteristics of the housing units or areas.


we can observe from the visual representation that:
    
X-axis: The x-axis represents the longitude values.
Each data point on the plot corresponds to a specific longitude value, indicating the location of the housing units or areas.

Y-axis: The y-axis represents the latitude values.
Each data point on the plot corresponds to a specific latitude value, 
indicating the geographic position of the housing units or areas.  


The dense concentrations of data points in the scatter plot
indicates that there are housing units or areas present in larger quantities at those specific longitude values.'''

# %% [markdown]
# # 8. Create a data set for which the ocean_proximity is ‘Near ocean’.

# %%
# step 1-Importing the necessary library:

import pandas as pd

# step 2-Assigning the file path to a variable:
original_dataset_path="C:\\Users\\RUBAI PANDEY\\Downloads\\housing.xlsx"

# step 3 -Reading the Excel file into a pandas DataFrame:
original_dataset = pd.read_excel(original_dataset_path)

# step 4-Filtering rows based on a condition:
near_ocean_dataset = original_dataset[original_dataset['ocean_proximity'] == 'NEAR OCEAN']

# step 5-printing the rows
print(near_ocean_dataset.head(5))
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850    -124.17     41.80                  16         2739           480.0
# 1851    -124.30     41.80                  19         2672           552.0
# 1852    -124.23     41.75                  11         3159           616.0
# 1853    -124.21     41.77                  17         3461           722.0
# 1854    -124.19     41.78                  15         3140           714.0
#
#       population  households  median_income  median_house_value  \
# 1850        1259         436         3.7557              109400
# 1851        1298         478         1.9797               85800
# 1852        1343         479         2.4805               73200
# 1853        1947         647         2.5795               68400
# 1854        1645         640         1.6654               74600
#
#      ocean_proximity
# 1850      NEAR OCEAN
# 1851      NEAR OCEAN
# 1852      NEAR OCEAN
# 1853      NEAR OCEAN
# ...

# %%
'''explanation:--
The code essentially reads the original dataset from the Excel file, filters the dataset to select only the rows
where 'ocean_proximity' is 'NEAR OCEAN', and then prints the first 5 rows of the resulting dataset.'''

# %% [markdown]
# # 9. Find the mean and median of the median income for the data set created in question 8.

# %%
# step 1-Importing the necessary library:
import pandas as pd

# step 2-Assigning the file path to a variable:
original_dataset_path = "C:\\Users\\RUBAI PANDEY\\Downloads\\housing.xlsx"

# step 3-Reading the Excel file into a pandas DataFrame:
original_dataset = pd.read_excel(original_dataset_path)

# step 4-Filtering rows based on a condition:
near_ocean_dataset = original_dataset[original_dataset['ocean_proximity'] == 'NEAR OCEAN']

# step 5-Calculating the mean and median of the 'median_income' column:
mean_median_income = near_ocean_dataset['median_income'].mean()
median_median_income = near_ocean_dataset['median_income'].median()

# step 6-Printing the mean and median of the median income:
print("Mean of Median Income:", mean_median_income)
print("Median of Median Income:", median_median_income)
# Out:
# Mean of Median Income: 4.0057848006019565
# Median of Median Income: 3.64705

# %%
'''explanation:--
After using the dataset that has been created in question no 8 and calculating the mean and median of the 'median income'
we can get the result.'''

# %% [markdown]
# # 10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

# %%
# step 1-Importing the necessary library:

import pandas as pd

# step 2-Assigning the file path to a variable:
original_dataset_path ="C:\\Users\\RUBAI PANDEY\\Downloads\\housing.xlsx"

# step 3-Reading the Excel file into a pandas DataFrame:
original_dataset = pd.read_excel(original_dataset_path)

# step 4-Creating a new column based on conditions:
original_dataset['total_bedroom_size'] = original_dataset['total_bedrooms'].apply(lambda x: 'small' if x <= 10 else 'medium' if x < 1000 else 'large')

# step 5-printing the result

print(original_dataset.head(5))
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY
#
#   total_bedroom_size
# 0             medium
# 1              large
# ...

# %%
'''explanation:-
The code essentially reads the original dataset from the Excel file, 
creates a new column 'total_bedroom_size' based on conditions applied to the 'total_bedrooms' column.

we can see that from the result that:--
1.If the value is less than or equal to 10, it is categorized as 'small'.
2.If the value is greater than 10 and less than 1000, it is categorized as 'medium'.
3.If the value is 1000 or greater, it is categorized as 'large'.'''
